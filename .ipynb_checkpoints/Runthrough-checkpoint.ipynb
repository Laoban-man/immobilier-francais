# %% [markdown]
# # Library imports

# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
import glob
from dask import dataframe as dd

# %%
file_path=os.path.join("..","data","valeurs-foncieres")
file_list=glob.glob(file_path+"/*.txt")
file_list
# Out:
# ['../data/valeurs-foncieres/valeursfoncieres-2018.txt',
#  '../data/valeurs-foncieres/valeursfoncieres-2017.txt',
#  '../data/valeurs-foncieres/valeursfoncieres-2015-s2.txt',
#  '../data/valeurs-foncieres/valeursfoncieres-2016.txt',
#  '../data/valeurs-foncieres/valeursfoncieres-2019.txt']

# %%
data_main=pd.read_csv(file_list[0],sep="|",decimal=",")
data_main=data_main[data_main["Code postal"]>=75000]
data_main=data_main[data_main["Code postal"]<76000]
for a in tqdm(range(1,len(file_list))):
    temp=pd.read_csv(file_list[a],sep="|",decimal=",")
    temp=temp[temp["Code postal"]>=75000]
    temp=temp[temp["Code postal"]<76000]
    data_main=pd.concat([data_main,temp])
    
data_main=data_main[['Date mutation', 'Nature mutation', 'Valeur fonciere', 'No voie', 'Code voie', 'Voie', 'Code commune','Nombre de lots','Code type local','Surface reelle bati', 'Nombre pieces principales']]
# Out:
# /home/nicolasrx/.pyenv/versions/3.7.6/envs/vivadata/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3156: DtypeWarning: Columns (14,18,23,24,26,28,32,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   0%|          | 0/4 [00:00<?, ?it/s]/home/nicolasrx/.pyenv/versions/3.7.6/envs/vivadata/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3156: DtypeWarning: Columns (18,23,24,26,28,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#  25%|██▌       | 1/4 [00:08<00:25,  8.56s/it]/home/nicolasrx/.pyenv/versions/3.7.6/envs/vivadata/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3156: DtypeWarning: Columns (18,23,24,26,28,30,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#  50%|█████     | 2/4 [00:12<00:11,  5.94s/it]/home/nicolasrx/.pyenv/versions/3.7.6/envs/vivadata/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3156: DtypeWarning: Columns (18,23,24,26,28,30,32,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#  75%|███████▌  | 3/4 [00:20<00:06,  6.85s/it]/home/nicolasrx/.pyenv/versions/3.7.6/envs/vivadata/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3156: DtypeWarning: Columns (18,23,24,26,28,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 100%|██████████| 4/4 [00:28<00:00,  7.19s/it]

# %%
data=data_main
data=pd.concat([data,pd.get_dummies(data["Nature mutation"],prefix="nature_mutation_")],axis=1)
data=pd.concat([data,pd.get_dummies(data["Code commune"],prefix="code_commune_")],axis=1)
data=pd.concat([data,pd.get_dummies(data["Code type local"],prefix="type_local_")],axis=1)
#data=pd.concat([data,pd.get_dummies(data["Code voie"],prefix="code_voie_")])
data.drop(["Date mutation","Nature mutation","Code commune","Code type local",'Code voie','Voie'],axis=1,inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 291360 entries, 3040983 to 3142951
# Data columns (total 37 columns):
#  #   Column                                               Non-Null Count   Dtype
# ---  ------                                               --------------   -----
#  0   Valeur fonciere                                      290605 non-null  float64
#  1   No voie                                              291319 non-null  float64
#  2   Nombre de lots                                       291360 non-null  int64
#  3   Surface reelle bati                                  285609 non-null  float64
#  4   Nombre pieces principales                            285609 non-null  float64
#  5   nature_mutation__Adjudication                        291360 non-null  uint8
#  6   nature_mutation__Echange                             291360 non-null  uint8
#  7   nature_mutation__Expropriation                       291360 non-null  uint8
#  8   nature_mutation__Vente                               291360 non-null  uint8
#  9   nature_mutation__Vente en l'état futur d'achèvement  291360 non-null  uint8
#  10  nature_mutation__Vente terrain à bâtir               291360 non-null  uint8
#  11  code_commune__12                                     291360 non-null  uint8
#  12  code_commune__40                                     291360 non-null  uint8
#  13  code_commune__101                                    291360 non-null  uint8
#  14  code_commune__102                                    291360 non-null  uint8
#  15  code_commune__103                                    291360 non-null  uint8
#  16  code_commune__104                                    291360 non-null  uint8
#  17  code_commune__105                                    291360 non-null  uint8
#  18  code_commune__106                                    291360 non-null  uint8
#  19  code_commune__107                                    291360 non-null  uint8
#  20  code_commune__108                                    291360 non-null  uint8
#  21  code_commune__109                                    291360 non-null  uint8
#  22  code_commune__110                                    291360 non-null  uint8
#  23  code_commune__111                                    291360 non-null  uint8
#  24  code_commune__112                                    291360 non-null  uint8
#  25  code_commune__113                                    291360 non-null  uint8
#  26  code_commune__114                                    291360 non-null  uint8
#  27  code_commune__115                                    291360 non-null  uint8
#  28  code_commune__116                                    291360 non-null  uint8
#  29  code_commune__117                                    291360 non-null  uint8
#  30  code_commune__118                                    291360 non-null  uint8
#  31  code_commune__119                                    291360 non-null  uint8
#  32  code_commune__120                                    291360 non-null  uint8
#  33  type_local__1.0                                      291360 non-null  uint8
#  34  type_local__2.0                                      291360 non-null  uint8
#  35  type_local__3.0                                      291360 non-null  uint8
#  36  type_local__4.0                                      291360 non-null  uint8
# dtypes: float64(4), int64(1), uint8(32)
# memory usage: 22.2 MB

# %%
data.head()
# Out:
#          Valeur fonciere  No voie  Nombre de lots  Surface reelle bati  \
# 3040983          50000.0      3.0               1                  0.0
# 3040984          50000.0      3.0               1                107.0
# 3041258          40000.0     26.0               1                  0.0
# 3041468         365000.0     11.0               2                 48.0
# 3041804         292000.0     28.0               1                 36.0
#
#          Nombre pieces principales  nature_mutation__Adjudication  \
# 3040983                        0.0                              0
# 3040984                        5.0                              0
# 3041258                        0.0                              0
# 3041468                        2.0                              0
# 3041804                        2.0                              0
#
#          nature_mutation__Echange  nature_mutation__Expropriation  \
# 3040983                         0                               0
# 3040984                         0                               0
# 3041258                         0                               0
# 3041468                         0                               0
# 3041804                         0                               0
#
#          nature_mutation__Vente  \
# 3040983                       1
# 3040984                       1
# 3041258                       1
# 3041468                       1
# 3041804                       1
#
#          nature_mutation__Vente en l'état futur d'achèvement  ...  \
# 3040983                                                  0    ...
# 3040984                                                  0    ...
# 3041258                                                  0    ...
# 3041468                                                  0    ...
# 3041804                                                  0    ...
#
#          code_commune__115  code_commune__116  code_commune__117  \
# 3040983                  0                  0                  0
# 3040984                  0                  0                  0
# 3041258                  0                  0                  0
# 3041468                  0                  0                  0
# 3041804                  0                  0                  0
#
#          code_commune__118  code_commune__119  code_commune__120  \
# 3040983                  0                  0                  0
# 3040984                  0                  0                  0
# 3041258                  0                  0                  0
# 3041468                  0                  0                  0
# 3041804                  0                  0                  0
#
#          type_local__1.0  type_local__2.0  type_local__3.0  type_local__4.0
# 3040983                0                0                1                0
# 3040984                0                1                0                0
# 3041258                0                0                1                0
# 3041468                0                1                0                0
# 3041804                0                1                0                0
#
# [5 rows x 37 columns]

# %%
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer


y=np.array(data["Valeur fonciere"]).reshape(len(y),1)
X=data.drop(["Valeur fonciere"],axis=1)

imp = SimpleImputer(missing_values=np.nan, strategy='mean')
y = imp.fit_transform(y)
KNN_imputer = KNNImputer(n_neighbors=10)
X = KNN_imputer.fit_transform(X)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import regularizers
# Define a function
def model(input_dim, regul=0, dropout=0):

    model = Sequential()

    # Add the first Dense layers of 100 units with the input dimension
    model.add(Dense(100, input_dim=input_dim, activation='relu', kernel_regularizer=regularizers.l2(regul)))

    # Add more layers of 100 units with regularization and then dropout
    model.add(Dense(100, activation='relu', kernel_regularizer=regularizers.l2(regul)))
    model.add(Dropout(dropout))
    model.add(Dense(100, activation='relu', kernel_regularizer=regularizers.l2(regul)))
    model.add(Dropout(dropout))
    model.add(Dense(100, activation='relu', kernel_regularizer=regularizers.l2(regul)))
    model.add(Dropout(dropout))
    model.add(Dense(100, activation='relu', kernel_regularizer=regularizers.l2(regul)))
    model.add(Dropout(dropout))
    
    # Add finally the output layer with one unit: the predicted result
    model.add(Dense(1, activation='linear', kernel_regularizer=regularizers.l2(regul)))
    
    return model


my_model = model(input_dim=X.shape[1])
opt = tf.keras.optimizers.Adam(learning_rate=0.1)
my_model.compile(loss="mse" , optimizer=opt, metrics=['mse','mae'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Scale the input features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train the model, iterating on the data in batches of 32 samples
history=my_model.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 3642/3642 [==============================] - 16s 4ms/step - loss: 1541002834204118.2500 - mse: 1541002834204118.2500 - mae: 4541891.7195 - val_loss: 1309594987003904.0000 - val_mse: 1309594987003904.0000 - val_mae: 4312282.0000
# Epoch 2/100
# 3642/3642 [==============================] - 15s 4ms/step - loss: 1428983174264397.5000 - mse: 1428983174264397.5000 - mae: 4327754.8054 - val_loss: 1309592571084800.0000 - val_mse: 1309592571084800.0000 - val_mae: 4312033.5000
# Epoch 3/100
# 3642/3642 [==============================] - 15s 4ms/step - loss: 1544589022828255.5000 - mse: 1544589022828255.5000 - mae: 4391769.7501 - val_loss: 1309589886730240.0000 - val_mse: 1309589886730240.0000 - val_mae: 4311791.5000
# Epoch 4/100
# 3642/3642 [==============================] - 15s 4ms/step - loss: 1473684461626839.5000 - mse: 1473684461626839.5000 - mae: 4344940.6771 - val_loss: 1309587202375680.0000 - val_mse: 1309587202375680.0000 - val_mae: 4311542.0000
# Epoch 5/100
# 3642/3642 [==============================] - 15s 4ms/step - loss: 1441898965837028.5000 - mse: 1441898965837028.5000 - mae: 4335272.4723 - val_loss: 1309584920674304.0000 - val_mse: 1309584920674304.0000 - val_mae: 4311298.0000
# Epoch 6/100
# 3642/3642 [==============================] - 16s 4ms/step - loss: 1458493182889589.2500 - mse: 1458493182889589.2500 - mae: 4365264.6578 - val_loss: 1309582504755200.0000 - val_mse: 1309582504755200.0000 - val_mae: 4311053.0000
# Epoch 7/100
# 3642/3642 [==============================] - 15s 4ms/step - loss: 1374285933603608.0000 - mse: 1374285933603608.0000 - mae: 4260389.9394 - val_loss: 1309581028360192.0000 - val_mse: 1309581028360192.0000 - val_mae: 4310808.0000
# Epoch 8/100
# 3642/3642 [==============================] - 16s 4ms/step - loss: 1475024696922212.0000 - mse: 1475024696922212.0000 - mae: 4352031.5501 - val_loss: 1309579149312000.0000 - val_mse: 1309579149312000.0000 - val_mae: 4310569.0000
# Epoch 9/100
# 3642/3642 [==============================] - 16s 4ms/step - loss: 1320122630552255.2500 - mse: 1320122630552255.2500 - mae: 4221556.5861 - val_loss: 1309577270263808.0000 - val_mse: 1309577270263808.0000 - val_mae: 4310325.0000
# Epoch 10/100
# 3642/3642 [==============================] - 16s 4ms/step - loss: 1456521436104536.0000 - mse: 1456521436104536.0000 - mae: 4305414.1609 - val_loss: 1309575659651072.0000 - val_mse: 1309575659651072.0000 - val_mae: 4310084.0000
# Epoch 11/100
# 3642/3642 [==============================] - 16s 4ms/step - loss: 1340053950424216.0000 - mse: 1340053950424216.0000 - mae: 4230330.0419 - val_loss: 1309573646385152.0000 - val_mse: 1309573646385152.0000 - val_mae: 4309840.0000
# Epoch 12/100
# 3642/3642 [==============================] - 16s 4ms/step - loss: 
100
# 3642/3642 [==============================] - 16s 4ms/step - loss: 1455454896256265.7500 - mse: 1455454896256265.7500 - mae: 4304238.2195 - val_loss: 1309391915581440.0000 - val_mse: 1309391915581440.0000 - val_mae: 4289981.0000
# Epoch 97/100
# 3642/3642 [==============================] - 16s 4ms/step - loss: 1411103284605754.5000 - mse: 1411103284605754.5000 - mae: 4322638.3374 - val_loss: 1309389633880064.0000 - val_mse: 1309389633880064.0000 - val_mae: 4289756.5000
# Epoch 98/100
# 3642/3642 [==============================] - 15s 4ms/step - loss: 1325990168369016.5000 - mse: 1325990168369016.5000 - mae: 4236087.2875 - val_loss: 1309387083743232.0000 - val_mse: 1309387083743232.0000 - val_mae: 4289537.0000
# Epoch 99/100
# 3642/3642 [==============================] - 16s 4ms/step - loss: 1618187765529630.0000 - mse: 1618187765529630.0000 - mae: 4444541.4367 - val_loss: 1309385473130496.0000 - val_mse: 1309385473130496.0000 - val_mae: 4289316.0000
# Epoch 100/100
# 3642/3642 [==============================] - 16s 4ms/step - loss: 1478832392490343.5000 - mse: 1478832392490343.5000 - mae: 4396112.2971 - val_loss: 1309383191429120.0000 - val_mse: 1309383191429120.0000 - val_mae: 4289089.0000

# %%
import matplotlib.pyplot as plt

print(history.history.keys())
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'mse', 'mae', 'val_loss', 'val_mse', 'val_mae'])

# %%
from folium.plugins import HeatMap
from plotnine import *
from geopandas import GeoDataFrame

# %%
shp_path = os.path.join("..","data","valeurs-foncieres",'gis_osm_roads_free_1.shp')
roads = GeoDataFrame.from_file(shp_path, encoding='utf-8')
roads.head()
# Out:
#    osm_id  code       fclass                      name   ref oneway  maxspeed  \
# 0    2569  5115     tertiary             Rue Nationale  None      F        50
# 1    2570  5114    secondary       Avenue des Gobelins  None      F        50
# 2    2573  5122  residential           Place des Alpes  None      F        30
# 3    2574  5115     tertiary                 Rue Taine  None      B        50
# 4  286314  5122  residential  Rue Saint-Louis en l'Île  None      B        50
#
#    layer bridge tunnel                                           geometry
# 0      0      F      F  LINESTRING (2.36944 48.82153, 2.36942 48.82159...
# 1      0      F      F    LINESTRING (2.35517 48.83202, 2.35531 48.83183)
# 2      0      F      F  LINESTRING (2.35858 48.83216, 2.35855 48.83218...
# 3      0      F      F  LINESTRING (2.39454 48.83943, 2.39430 48.83927...
# 4      0      F      F    LINESTRING (2.36009 48.85041, 2.36007 48.85046)

# %%
print(roads["name"][300:370])
# Out:
# 300        Quai de l'Archevêché
# 301           Rue du Chevaleret
# 302          Rue de la Chapelle
# 303                Rue Proudhon
# 304                  Rue Bruant
#                  ...
# 365            Rue Jeanne d'Arc
# 366        Passage Commun AS/13
# 367       Boulevard Saint-Denis
# 368    Boulevard Vincent Auriol
# 369              Rue Abel Gance
# Name: name, Length: 70, dtype: object

# %%
center = [48.85537, 2.35422]
top = 48.890404
bottom = 48.79120
left = 2.281760
right = 2.417716

# %%
import folium
import shapely.affinity
from shapely.geometry import Point
import geopy
import geopy.distance

# create an ellipse
radius_lat = geopy.distance.distance(kilometers = 10).destination(point=center, bearing=0)[0] - center[0]
radius_lon = geopy.distance.distance(kilometers = 10).destination(point=center, bearing=90)[1] - center[1]

circle = Point(center[::-1]).buffer(1)
ellipse = shapely.affinity.scale(circle, radius_lon, radius_lat)

ellipse_map = folium.Map(location=center, zoom_start=10, tiles='CartoDB positron')

folium.PolyLine(list([c[::-1] for c in ellipse.exterior.coords])).add_to(ellipse_map)

ellipse_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7c84c9e76f904b3c9eb1495bc2d88b6a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7c84c9e76f904b3c9eb1495bc2d88b6a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7c84c9e76f904b3c9eb1495bc2d88b6a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7c84c9e76f904b3c9eb1495bc2d88b6a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B48.85537%2C%202.35422%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
paris = roads.loc[roads['geometry'].apply(lambda g: ellipse.contains(g))].copy()
paris.shape
# Out:
# (106793, 11)

# %%
paris = paris[paris.fclass.isin(['trunk', 'primary','secondary','tertiary']) | paris['name'].notnull()]
paris['name'] = paris['name'].fillna(value='')
paris.shape
# Out:
# (47412, 11)

# %%
paris['prefix'] = paris['name'].apply(lambda name: name.split(' ')[0] if name is not None else None)
paris['suffix'] = paris['name'].apply(lambda name: name.split(' ')[-1] if name is not None else None)

# %%
def get_designation(name):
    name = name.lower()
    if 'rue' in name: return 'rue'
    elif 'avenue' in name: return 'avenue'
    elif 'allée' in name: return 'allée'
    elif 'place' in name: return 'place'
    elif 'boulevard' in name: return 'boulevard'
    elif 'passage' in name: return 'passage'
    elif 'quai' in name: return 'quai'
    elif 'route' in name: return 'route'
    else: return "autre"


paris['designation'] = [get_designation(name) for name in paris['name']]

# %%
paris.head()
# Out:
#    osm_id  code       fclass                      name   ref oneway  maxspeed  \
# 0    2569  5115     tertiary             Rue Nationale  None      F        50
# 1    2570  5114    secondary       Avenue des Gobelins  None      F        50
# 2    2573  5122  residential           Place des Alpes  None      F        30
# 3    2574  5115     tertiary                 Rue Taine  None      B        50
# 4  286314  5122  residential  Rue Saint-Louis en l'Île  None      B        50
#
#    layer bridge tunnel                                           geometry  \
# 0      0      F      F  LINESTRING (2.36944 48.82153, 2.36942 48.82159...
# 1      0      F      F    LINESTRING (2.35517 48.83202, 2.35531 48.83183)
# 2      0      F      F  LINESTRING (2.35858 48.83216, 2.35855 48.83218...
# 3      0      F      F  LINESTRING (2.39454 48.83943, 2.39430 48.83927...
# 4      0      F      F    LINESTRING (2.36009 48.85041, 2.36007 48.85046)
#
#    prefix     suffix designation
# 0     Rue  Nationale         rue
# 1  Avenue   Gobelins      avenue
# 2   Place      Alpes       place
# 3     Rue      Taine         rue
# 4     Rue      l'Île         rue

# %%
colors = {
    'rue': '#59c8e5',
    'avenue': '#59c8e5',
    'allée': '#fed032',
    'place': '#fec301',
    'boulevard': '#fe4d64',
    'passage': '#ffb366',
    'quai': '#ff9223',
    'route': '#0a7abf'
    'autre': '#cccccc'
}

# %%
import math
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

def plot_and_save(
    top,bottom,left,right,linewidth,linewidth_lane,legend_title,legend_bbox,path,colors,dpi=300):
    
    f, ax = plt.subplots(1, figsize=(15, 15))

    paris.plot(ax=ax)#color=[colors[d] for d in paris.designation],linewidth=[linewidth if d == 'place' else linewidth_lane for d in paris.designation])
    ax.set_aspect(1/math.cos(math.pi/180*center[0]))
    ax.set_ylim((bottom, top))
    ax.set_xlim((left, right))
    plt.axis('off')
    plt.legend(handles=[mpatches.Patch(color=colors[k], label=k) for k in colors],
               loc='center right',fontsize='large', edgecolor='none', title=legend_title,title_fontsize='xx-large',bbox_to_anchor=legend_bbox)

    plt.savefig(path, bbox_inches='tight', dpi=dpi)

# %%
plot_and_save(top,bottom,left,right,
              1,0.7,'Paris',(1.25, 0.5),'paris.png',colors=colors)
